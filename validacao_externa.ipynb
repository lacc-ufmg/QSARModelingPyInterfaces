# %%
import numpy as np

# %%
import pandas as pd

# %%
from validacao_externa import ExternalValidation

# %%
directory = "/home/jpam/Dropbox/eduardo/UEM/beta_carbonilicos/modelo/"

# %%
dfX = pd.read_csv(directory+"XSellno.csv",sep='\t')
y = pd.read_csv(directory+"Atividade-classe.txt",sep=';',header=None).values
X = dfX.values

# %%
ext = ExternalValidation(X,y)

# %%
ext.searchValidExtVal()
# Out:
# /home/jpam/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# Warning
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# Warning
# bad
# bad
# bad

# %%
ext.R2
# Out:
# array([], dtype=float64)

# %%
ext.Q2
# Out:
# array([], dtype=float64)

# %%
ext.tests_sets

# %%
ext.runValidExtVal(directory,n_models=5)

# %%
test = [5, 13, 21, 23, 25, 27, 32, 37, 40, 47]

# %%
train = [j for j in range(len(y)) if j not in test]

# %%
ext.extVal(train,test,nLV=2)

# %%
ext.saveExtVal(train,test,directory+"saidaextval2LV.csv")

# %%
ext.validateExtVal(train,test,nLV=2)
