# %%
import numpy as np
import pandas as pd

# %%
directoryExt = "/home/jpam/MEGA/eduardo/DAT/triagem/LQTAGridFiles/"
directoryTrain = "/home/jpam/MEGA/eduardo/DAT/LQTAGridFiles/"

# %%
dfX = pd.read_csv(directoryTrain+"Xtrain.csv",sep=';',index_col=0)
y = pd.read_csv(directoryTrain+"ytrain.csv",sep=',',header=None,index_col=0).values
X = dfX.values

# %%
dfX.columns
# Out:
# Index(['5.00_8.00_14.00_NH3+_C:', '10.00_25.00_11.00_NH3+_C:',
#        '12.00_6.00_23.00_NH3+_C:', '12.00_18.00_14.00_NH3+_C:',
#        '15.00_18.00_9.00_NH3+_C:', '16.00_10.00_16.00_NH3+_C:',
#        '17.00_23.00_9.00_NH3+_C:', '20.00_20.00_12.00_NH3+_C:',
#        '22.00_18.00_10.00_NH3+_C:', '22.00_20.00_19.00_NH3+_C:',
#        '26.00_15.00_2.00_NH3+_C:', '30.00_18.00_7.00_NH3+_C:',
#        '30.00_28.00_-2.00_NH3+_C:', '7.00_18.00_13.00_NH3+_LJ:',
#        '16.00_19.00_11.00_NH3+_LJ:', '18.00_11.00_16.00_NH3+_LJ:',
#        '20.00_16.00_13.00_NH3+_LJ:', '21.00_26.00_10.00_NH3+_LJ:',
#        '24.00_18.00_12.00_NH3+_LJ:', '24.00_25.00_12.00_NH3+_LJ:',
#        '24.00_26.00_18.00_NH3+_LJ:', '29.00_16.00_12.00_NH3+_LJ:'],
#       dtype='object')

# %%
dfXext = pd.read_csv(directoryExt+"matriz_previsao4D.csv",sep=';',index_col=0)

# %%
desc = dfX.columns

# %%
from lj_cut import transform

# %%
dfExt = transform(dfXext)

# %%
dfXextSel = dfExt.loc[:,desc]

# %%
from cross_validation_class import CrossValidation

# %%
cv = CrossValidation(X,y)

# %%
cv.Q2()
# Out:
# [0.7553462168639236,
#  0.8464756241535305,
#  0.8070002102308105,
#  0.5933680256210881,
#  0.5565459509696223,
#  0.5956234942063734,
#  0.594050749952654]

# %%
nLV = 3

# %%
from sklearn.cross_decomposition import PLSRegression

# %%
pls = PLSRegression(n_components = nLV)

# %%
pls.fit(X,y)
# Out:
# PLSRegression(copy=True, max_iter=500, n_components=3, scale=True, tol=1e-06)

# %%
yp = pls.predict(dfXextSel.values)

# %%
yp
# Out:
# array([[6.31284255],
#        [6.39867413],
#        [6.3349762 ],
#        [7.79168512],
#        [7.06640557],
#        [6.86170295],
#        [6.66835811],
#        [6.60953911],
#        [7.38761612],
#        [5.79790525],
#        [9.86985658],
#        [5.29703068]])

# %%
dfXextSel.to_csv(directoryExt+"Xprevisao4D.csv",sep=';')

# %%
dfYp = pd.DataFrame(yp,index=dfXextSel.index)

# %%
dfYp.to_csv(directoryExt+"yprevisto4D.csv",header=False)

# %%
y
# Out:
# array([[4.714],
#        [5.384],
#        [5.521],
#        [5.077],
#        [4.684],
#        [4.932],
#        [5.907],
#        [6.229],
#        [4.866],
#        [5.174],
#        [6.011],
#        [6.141],
#        [6.355],
#        [6.652],
#        [6.623],
#        [5.939],
#        [6.393],
#        [6.848],
#        [6.529],
#        [6.362],
#        [6.53 ],
#        [6.943],
#        [6.213],
#        [5.658],
#        [8.446],
#        [8.347],
#        [7.305],
#        [7.777],
#        [8.131],
#        [8.303],
#        [7.714],
#        [8.595],
#        [7.326],
#        [7.544],
#        [6.67 ],
#        [6.558],
#        [7.231]])
