# %%
# Importing libraries
import numpy as np
import pandas as pd
from modules.ga import Ga
from modules.cross_validation_class import CrossValidation
from modules.yrandomization import YRandomization
from modules.lno import LNO
from modules.filter import variance_cut,correlation_cut,autocorrelation_cut
import modules.lj_cut as lj
from modules.validate_yr_lno import validate
import os

# %%
# Open configuration file in order to look for the matrices and the parameters to run
# GA and cross-validation
dfConf = pd.read_csv("/home/helitonmrf/OneDrive/Documentos/QSAR/Amostragem por Fecho Convexo/Descritores 4D/matrizes_C_LJ/confGA.csv",header=None)
directory = dfConf[1][0]
xFile = dfConf[1][1]
yFile = dfConf[1][2]
var_cut = float(dfConf[1][3])
corr_cut = float(dfConf[1][4])
nLVModel = None if dfConf.isnull()[1][5] else int(dfConf[1][5])
min_size = int(dfConf[1][6])
max_size = int(dfConf[1][7])
size_population = int(dfConf[1][8])
mig_rate = float(dfConf[1][9])
cxpb = float(dfConf[1][10])
mutpb = float(dfConf[1][11])
ngen = int(dfConf[1][12])
yr_crit = float(dfConf[1][13])
lno_crit = float(dfConf[1][14])
out_directory = dfConf[1][15]
out_matrix = dfConf[1][16]
out_cv = dfConf[1][17]
Q2_file = dfConf[1][18]
var_sel_file = dfConf[1][19]
autoscale = dfConf[1][20].upper() == "YES"
df = pd.read_csv(os.path.join(directory,xFile),sep=';',index_col=0)
# Filtering the matrix according to the options in configuration file
dfX = lj.transform(df) if dfConf[1][21].upper() == "YES" else df
#dfX = dfX.drop(["teste_alinha/dez_a.mol2","teste_alinha/dez_e.mol2","teste_alinha/onze_a.mol2"])
print("Dimensions of the original matrix")
print(dfX.shape)
y = pd.read_csv(os.path.join(directory,yFile),sep=';',header=None).values
indVar = variance_cut(dfX.values,var_cut)
dfVar = dfX.loc[:,dfX.columns[indVar]]
print("Dimensions of the matrix after variance cut")
print(dfVar.shape)
indCorr = correlation_cut(dfVar.values,y,corr_cut)
dfCorr = dfVar.loc[:,dfVar.columns[indCorr]]
print("Dimensions of the matrix after correlation cut")
print(dfCorr.shape)
auto_cut = dfConf[1][22]
indAuto = autocorrelation_cut(dfCorr.values,y,auto_cut)
dfRest = dfCorr.iloc[:,indAuto]
print("Dimensions of the matrix after auto correlation cut")
print(dfRest.shape)
dfRest.to_csv(os.path.join(out_directory,"filtered_"+out_matrix),sep=';')
X = dfRest.values
if nLVModel == None:
    nLVModel = dfCorr.shape[0]
ga = Ga(X,y,nLVModel, autoscale, min_size, max_size, size_population, mig_rate, cxpb, mutpb, ngen)
ga.run()
ga.saveQ2(out_directory+"/"+Q2_file)
ga.savePop(out_directory+"/"+var_sel_file)
Q2 = ga.Q2
Q2 = [Q2[i][0] for i,_ in enumerate(Q2)]
var_sel = validate(X,y,ga.pop_selected,Q2,yr_cut=yr_crit,lno_cut=lno_crit)
if var_sel != []:
    dfSel = dfCorr.loc[:,dfCorr.columns[var_sel]]
    dfSel.to_csv(os.path.join(out_directory,out_matrix),sep=';')
    cv = CrossValidation(dfSel.values,y)
    cv.saveParameters(os.path.join(out_directory,out_cv))        
else:
    print("y-randomization or LNO failed!")
# Out:
# Dimensions of the original matrix
# (33, 12260)
# Dimensions of the matrix after variance cut
# (33, 10273)
# Dimensions of the matrix after correlation cut
# (33, 2187)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-68b8e0766a3a> in <module>
#      39 print(dfCorr.shape)
#      40 auto_cut = dfConf[1][22]
# ---> 41 indAuto = autocorrelation_cut(dfCorr.values,y,auto_cut)
#      42 dfRest = dfCorr.iloc[:,indAuto]
#      43 print("Dimensions of the matrix after auto correlation cut")
#
# ~/Documentos/QSARmodelingPysrc/filter.py in autocorrelation_cut(X, y, cut)
#      29             if Xcorr[i,j] > 0.9:
#      30                 corr_i = abs(np.dot(np.transpose(autoscale(X[:,i])),autoscale(y))/(len(y)-1))
# ---> 31                 corr_j = abs(np.dot(np.transpose(autoscale(X[:,j])),autoscale(y))/(len(y)-1))
#      32                 if i < j:
#      33                     if i not in var_filtered:
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py in scale(X, axis, with_mean, with_std, copy)
#     186                 # due to the lack of precision of mean_. A solution is then to
#     187                 # subtract the mean again:
# --> 188                 if not np.allclose(mean_2, 0):
#     189                     warnings.warn("Numerical issues were encountered "
#     190                                   "when scaling the data "
#
# <__array_function__ internals> in allclose(*args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py in allclose(a, b, rtol, atol, equal_nan)
#    2169
#    2170     """
# -> 2171     res = all(isclose(a, b, rtol=rtol, atol=atol, equal_nan=equal_nan))
#    2172     return bool(res)
#    2173
#
# <__array_function__ internals> in isclose(*args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py in isclose(a, b, rtol, atol, equal_nan)
#    2269     xfin = isfinite(x)
#    2270     yfin = isfinite(y)
# -> 2271     if all(xfin) and all(yfin):
#    2272         return within_tol(x, y, atol, rtol)
#    2273     else:
#
# <__array_function__ internals> in all(*args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in all(a, axis, out, keepdims)
#    2349
#    2350     """
# -> 2351     return _wrapreduction(a, np.logical_and, 'all', axis, None, out, keepdims=keepdims)
#    2352
#    2353
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      86                 return reduction(axis=axis, dtype=dtype, out=out, **passkwargs)
#      87             else:
# ---> 88                 return reduction(axis=axis, out=out, **passkwargs)
#      89
#      90     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py in _all(a, axis, dtype, out, keepdims)
#      45     return umr_any(a, axis, dtype, out, keepdims)
#      46
# ---> 47 def _all(a, axis=None, dtype=None, out=None, keepdims=False):
#      48     return umr_all(a, axis, dtype, out, keepdims)
#      49
#
# KeyboardInterrupt:

# %%
var_sel = validate(X,y,ga.pop_selected,Q2,yr_cut=yr_crit,lno_cut=lno_crit)

# %%
print(var_sel)
# Out:
# []
