# %% [markdown]
# # QSARModeling - Jupyter Notebook
#
# You're running QSAR Modeling Jupyter Notebook version. Please select the desired function below.
#
# ## Use Widgets (graphics)
# - [Cross Validation](./Notebooks/cross_validation_widgets.ipynb)
# - [External Validation](./Notebooks/external_validation_widgets.ipynb)
# - [Run Genetic Algorithm (GA)](./Notebooks/runGA_widgets.ipynb)
# - [Run Ordered Predictors Selection (OPS)](./Notebooks/runOPS_widgets.ipynb)
#
#
# ## Don't use widgets (graphics)
#
# - [Cross Validation](./Notebooks/cross_validation.ipynb)
# - [External Validation](./Notebooks/external_validation.ipynb)
# - [Mount prediction matrix](./Notebooks/mount_prediction_matrix.ipynb)
# - [Predict external set](./Notebooks/predict_external_set.ipynb)
# - [Predict real external set](./Notebooks/predict_real_external_set.ipynb)
# - [Run Genetic Algorithm (GA)](./Notebooks/runGA.ipynb)
# - [Run Ordered Predictors Selection (OPS)](./Notebooks/runOPS.ipynb)
# - [Run y-randomization and Leave-N-Out](./Notebooks/run_yr_lno.ipynb)
